# %%
# Calculate the arithmetic mean of a list of numbers.
def calculate_average(numbers):
    # Return 0 if the input list is empty to avoid division by zero
    if not numbers:
        return 0

    # Compute and return the arithmetic mean of the numbers
    return sum(numbers) / len(numbers)
